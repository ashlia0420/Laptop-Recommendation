# %%
import pandas as pd

# %%
df = pd.read_csv(
    r"C:\Users\LESLIN\Downloads\csv\laptop_kaggle.csv"
)

# %%
df
# Out:
#       Unnamed: 0                                         model_name    brand  \
# 0              0                Lenovo V15 ITL G2 82KBA033IH Laptop   Lenovo
# 1              1              HP Pavilion 15-ec2004AX Gaming Laptop       HP
# 2              2                       Lenovo V15 82KBA03HIH Laptop   Lenovo
# 3              3      Asus Vivobook 16X 2022 M1603QA-MB502WS Laptop     Asus
# 4              4                             HP 15s-fr4000TU Laptop       HP
# ...          ...                                                ...      ...
# 1009        1013                     Fujitsu UH-X 4ZR1F38024 Laptop  Fujitsu
# 1010        1014                      Asus BR1100CKA-GJ0722W Laptop     Asus
# 1011        1015             Lenovo Yoga 6 13ALC6 82ND00DPIN Laptop   Lenovo
# 1012        1016                      Asus BR1100FKA-BP1104W Laptop     Asus
# 1013        1017  Asus ROG Strix Scar 17 G733ZW-LL139WS Gaming L...     Asus
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                     model_name   brand  \
# 0           0            Lenovo V15 ITL G2 82KBA033IH Laptop  Lenovo
# 1           1          HP Pavilion 15-ec2004AX Gaming Laptop      HP
# 2           2                   Lenovo V15 82KBA03HIH Laptop  Lenovo
# 3           3  Asus Vivobook 16X 2022 M1603QA-MB502WS Laptop    Asus
# 4           4                         HP 15s-fr4000TU Laptop      HP
#
#       processor_name  ram(GB)  ssd(GB)  Hard Disk(GB) Operating System  \
# 0   11th Gen Core i3        8      512              0          Windows
# 1  AMD Ryzen 5 5600H        8      512              0          Windows
# 2   11th Gen Core i3        8      256           1000          Windows
# 3      Ryzen 5-5600H        8      512              0          Windows
# 4   11th Gen Core i5        8      512              0          Windows
#
#                        graphics  screen_size(inches) resolution (pixels)  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Unnamed: 0             1014
# model_name              924
# brand                    22
# processor_name          123
# ram(GB)                   6
# ssd(GB)                   7
# Hard Disk(GB)             5
# Operating System          5
# graphics                156
# screen_size(inches)      21
# resolution (pixels)      30
# no_of_cores               9
# no_of_threads             9
# spec_score               49
# price                   623
# dtype: int64

# %%
df["brand"].unique()
# Out:
# array(['Lenovo', 'HP', 'Asus', 'Dell', 'Realme', 'Acer', 'MSI', 'Infinix',
#        'Nokia', 'Samsung', 'Microsoft', 'Xiaomi', 'Honor', 'Chuwi',
#        'Gigabyte', 'AGB', 'Fujitsu', 'Huawei', 'Avita', 'LG'],
#       dtype=object)

# %%
 df["processor_name"].unique()
# Out:
# array(['11th Gen Core i3', 'AMD Ryzen 5 5600H', 'Ryzen 5-5600H',
#        '11th Gen Core i5', 'AMD Athlon Silver 3050U', '12th Gen Core i3',
#        'Ryzen 7 5800H', '12th Gen Core i5', 'AMD Ryzen 5 4600H',
#        'AMD Ryzen 3 3250U', '10th Gen Core i3', 'AMD Ryzen 5 5500U',
#        'AMD Ryzen 3 5300U', 'AMD Ryzen 3  3250U', '12th Gen Core i7',
#        'Ryzen 5 5600H', '11th Gen Core i7', 'AMD Ryzen 5-5600H',
#        'Ryzen 7-4800H', 'Ryzen 5 7520U', '13th Gen Core i7',
#        '13th Gen Core i5', 'AMD Ryzen 5-5625U', 'Ryzen 5 5500U',
#        'AMD Ryzen 7 6800H', '10th Gen Core i5', '11th Gen Core i9',
#        'Pentium Silver N6000', '12th Gen Core i9',
#        '2022) FX507ZE-HN038W Gaming Laptop ', 'AMD Ryzen 7 4800H',
#        'AMD Ryzen 5 3500U', 'Athlon Silver 3050U', '8LX79PA) Laptop ',
#        'Ryzen 3 5300U', 'Athlon 3050U', 'AMD Ryzen 7 5800H',
#        'Athlon Pro 3045B', 'Ryzen 7 5700U', 'AMD Ryzen 3 5425U',
# ...

# %%
 df["ram(GB)"].unique()
# Out:
# array([ 8, 16, 64, 32, 12], dtype=int64)

# %%
 df["ssd(GB)"].unique()
# Out:
# array([ 512,  256,    0, 1000, 2000,  128, 4000], dtype=int64)

# %%
 df["Hard Disk(GB)"].unique()
# Out:
# array([   0, 1000], dtype=int64)

# %%
df["Operating System"].unique()
# Out:
# array(['Windows', 'DOS', 'Ubuntu'], dtype=object)

# %%
df["graphics"].unique()
# Out:
# array(['Intel Integrated UHD', '4\u2009GB NVIDIA GeForce GTX 1650',
#        'AMD Radeon Vega 7', 'Intel Integrated Iris Xe',
#        'AMD Radeon Graphics', 'Intel UHD Graphics', 'Intel Iris Xe',
#        'AMD Radeon', 'Intel Iris Xe Graphics',
#        'AMD Radeon Vega 7 Graphics', '4\u2009GB NVIDIA GeForce RTX 3050',
#        '4\u2009GB AMD Radeon RX 5500M', 'Intel Iris XE Graphics',
#        '4\u2009GB NVIDIA GeForce GTX 1650 Max Q',
#        '4\u2009GB NVIDIA GeForce RTX 2050',
#        'Intel Integrated Intel Iris Xe Graphics',
#        '\u200eIntel Iris Xe Graphics',
#        '4\u2009GB NVIDIA GeForce GTX 1650 MAX Q', 'AMD Radeon Graphiics',
#        'AMD Radeon Radeon Graphics',
#        '4\u2009GB NVIDIA GeForce RTX 3050 Ti', 'Intel Iris Xᵉ Graphics',
#        'AMD Radeon AMD', 'Intel iris Xe Integrated',
#        '2\u2009GB NVIDIA GeForce MX330',
#        'Intel Integrated Iris Xe Graphics',
#        '2\u2009GB NVIDIA GeForce MX550', '8\u2009GB AMD Radeon RX 6650M',
# ...

# %%
df["screen_size(inches)"].unique()
# Out:
# array([15.6 , 16.  , 15.56, 14.  , 17.3 , 13.3 , 14.1 , 16.1 , 12.4 ,
#        13.  , 13.5 , 14.5 , 13.4 , 15.  , 17.32, 17.  ])

# %%
df["resolution (pixels)"].unique()
# Out:
# array(['1920 x 1080', '1200 x 1920', '1366 x 768', '1440 x 2160',
#        '1920 x 1200', '2880 x 1800', '2560 x 1920', '1080 x 1920',
#        '1536 x 1024', '2880 x 1920', '2560 x 1440', '3840 x 2400',
#        '2560 x 1600', '2160 x 1440', '2256 x 1504', '3840 x 2160',
#        '3200 x 2000', '2496 x 1664', '2560 x 1660', '1920 x 1280',
#        '3000 x 2000', '3072 x 1920', '2240 x 1400', '1600 x 2560',
#        '2304 x 1400'], dtype=object)

# %%
df["no_of_cores"].unique()
# Out:
# array([ 2,  6,  4,  8, 10, 12, 14, 16], dtype=int64)

# %%
df["no_of_threads"].unique()
# Out:
# array([ 4, 12,  8,  2, 16, 20, 24,  6], dtype=int64)

# %%
df["spec_score"].unique()
# Out:
# array([62, 66, 63, 73, 57, 61, 59, 68, 60, 55, 69, 72, 67, 51, 56, 41, 53,
#        74, 65, 71, 44, 54, 80, 75, 81, 82, 76, 50, 88, 79, 84, 48, 47, 78,
#        45, 49, 86, 85, 97, 91, 90, 96, 94, 42, 87, 93, 92], dtype=int64)

# %%
df[df["graphics"] == "Missing"]
# Out:
#       Unnamed: 0                                  model_name    brand  \
# 6              6              Infinix Zero Book Ultra Laptop  Infinix
# 275          279      Dell Inspiron 7420 D560780WIN9S Laptop     Dell
# 315          319             Lenovo E41-55 82FJ009JIH Laptop   Lenovo
# 594          598         Acer Nitro 5 AN515-46 Gaming Laptop     Acer
# 712          716                         HP 255 G8 R3 Laptop       HP
# 993          997                Lenovo V15 82KB0003GE Laptop   Lenovo
# 1004        1008  Asus VivoBook 14 2021 X415MA-BV011W Laptop     Asus
# 1008        1012             Asus BR1100CKA-GJ0722W Notebook     Asus
#
#          processor_name  ram(GB)  ssd(GB)  Hard Disk(GB) Operating System  \
# 6      12th Gen Core i9       16      512              0          Windows
# 275    12th Gen Core i3        8      256              0          Windows
# 315    Athlon Pro 3045B        4        0           1000              DOS
# ...

# %%
df = df[df["graphics"] != "Missing"]

# %%
df[df["model_name"] == "Missing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, model_name, brand, processor_name, ram(GB), ssd(GB), Hard Disk(GB), Operating System, graphics, screen_size(inches), resolution (pixels), no_of_cores, no_of_threads, spec_score, price]
# Index: []

# %%
df["screen_size(inches)"].value_counts(dropna=False)
# Out:
# screen_size(inches)
# 15.60    502
# 14.00    260
# 16.00     55
# 13.30     51
# 17.30     30
# 16.10     25
# 13.40     20
# 14.10     13
# 13.50      6
# 15.00      5
# 11.60      5
# 14.50      5
# 13.60      4
# 16.20      4
# 13.00      4
# 14.20      4
# 17.32      3
# 12.40      3
# 15.56      3
# 17.00      3
# 10.10      1
# Name: count, dtype: int64

# %%
df["screen_size(inches)"].unique()
# Out:
# array([15.6 , 16.  , 15.56, 13.3 , 14.  , 13.6 , 17.3 , 10.1 , 14.1 ,
#        16.1 , 12.4 , 16.2 , 13.  , 11.6 , 14.2 , 13.5 , 14.5 , 13.4 ,
#        15.  , 17.32, 17.  ])

# %%
df["resolution (pixels)"].unique()
# Out:
# array(['1920 x 1080', '1200 x 1920', '1366 x 768', '2560 x 1600',
#        '1440 x 2160', '1920 x 1200', '2560 x 1664', '1200 x 800',
#        '2880 x 1800', '2560 x 1920', '1080 x 1920', '1536 x 1024',
#        '3456 x 2234', '2880 x 1920', '2560 x 1440', '3840 x 2400',
#        '3024 x 1964', '2160 x 1440', '2256 x 1504', '3840 x 2160',
#        '3200 x 2000', '768 x 1366', '2496 x 1664', nan, '2560 x 1660',
#        '1920 x 1280', '3000 x 2000', '3072 x 1920', '2240 x 1400',
#        '1600 x 2560', '2304 x 1400'], dtype=object)

# %%
df["resolution (pixels)"].value_counts(dropna=False)
# Out:
# resolution (pixels)
# 1920 x 1080    674
# 1366 x 768      71
# 2560 x 1440     51
# 2880 x 1800     44
# 1920 x 1200     41
# 2560 x 1600     35
# 3840 x 2400     17
# 3840 x 2160     12
# 1080 x 1920      8
# 1200 x 1920      5
# 1600 x 2560      5
# 2560 x 1664      4
# 3024 x 1964      4
# 3456 x 2234      4
# 2880 x 1920      3
# 1440 x 2160      3
# 2160 x 1440      3
# 1536 x 1024      3
# 3000 x 2000      3
# 2256 x 1504      2
# 2240 x 1400      2
# 2496 x 1664      2
# 2560 x 1660      2
# 1920 x 1280      1
# 3072 x 1920      1
# 1200 x 800       1
# NaN              1
# 768 x 1366       1
# 3200 x 2000      1
# 2560 x 1920      1
# 2304 x 1400      1
# Name: count, dtype: int64

# %%
df = df.dropna(subset=["resolution (pixels)"])

# %%
df["resolution (pixels)"].value_counts(dropna=False)
# Out:
# resolution (pixels)
# 1920 x 1080    674
# 1366 x 768      71
# 2560 x 1440     51
# 2880 x 1800     44
# 1920 x 1200     41
# 2560 x 1600     35
# 3840 x 2400     17
# 3840 x 2160     12
# 1080 x 1920      8
# 1200 x 1920      5
# 1600 x 2560      5
# 3456 x 2234      4
# 3024 x 1964      4
# 2560 x 1664      4
# 1536 x 1024      3
# 2880 x 1920      3
# 1440 x 2160      3
# 3000 x 2000      3
# 2160 x 1440      3
# 2496 x 1664      2
# 2256 x 1504      2
# 2240 x 1400      2
# 2560 x 1660      2
# 3072 x 1920      1
# 1200 x 800       1
# 1920 x 1280      1
# 768 x 1366       1
# 3200 x 2000      1
# 2560 x 1920      1
# 2304 x 1400      1
# Name: count, dtype: int64

# %%
df["price"].value_counts(dropna=False)
# Out:
# price
# 57990     12
# 85990     11
# 79990      9
# 54990      9
# 89990      9
#           ..
# 149899     1
# 70816      1
# 84419      1
# 40960      1
# 134490     1
# Name: count, Length: 620, dtype: int64

# %%
df = df.dropna(subset=["price"])

# %%
df["price"].value_counts(dropna=False)
# Out:
# price
# 57990     12
# 85990     11
# 79990      9
# 54990      9
# 89990      9
#           ..
# 149899     1
# 70816      1
# 84419      1
# 40960      1
# 134490     1
# Name: count, Length: 620, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'model_name', 'brand', 'processor_name', 'ram(GB)',
#        'ssd(GB)', 'Hard Disk(GB)', 'Operating System', 'graphics',
#        'screen_size(inches)', 'resolution (pixels)', 'no_of_cores',
#        'no_of_threads', 'spec_score', 'price'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Unnamed: 0                             model_name   brand  \
# 0           0    Lenovo V15 ITL G2 82KBA033IH Laptop  Lenovo
# 1           1  HP Pavilion 15-ec2004AX Gaming Laptop      HP
# 2           2           Lenovo V15 82KBA03HIH Laptop  Lenovo
#
#       processor_name  ram(GB)  ssd(GB)  Hard Disk(GB) Operating System  \
# 0   11th Gen Core i3        8      512              0          Windows
# 1  AMD Ryzen 5 5600H        8      512              0          Windows
# 2   11th Gen Core i3        8      256           1000          Windows
#
#                        graphics  screen_size(inches) resolution (pixels)  \
# 0          Intel Integrated UHD                 15.6         1920 x 1080
# 1  4 GB NVIDIA GeForce GTX 1650                 15.6         1920 x 1080
# 2          Intel Integrated UHD                 15.6         1920 x 1080
#
#    no_of_cores  no_of_threads  spec_score  price
# 0            2              4          62  33921
# ...

# %%
df.drop(columns=["Unnamed: 0"])
# Out:
#                                              model_name    brand  \
# 0                   Lenovo V15 ITL G2 82KBA033IH Laptop   Lenovo
# 1                 HP Pavilion 15-ec2004AX Gaming Laptop       HP
# 2                          Lenovo V15 82KBA03HIH Laptop   Lenovo
# 3         Asus Vivobook 16X 2022 M1603QA-MB502WS Laptop     Asus
# 4                                HP 15s-fr4000TU Laptop       HP
# ...                                                 ...      ...
# 1009                     Fujitsu UH-X 4ZR1F38024 Laptop  Fujitsu
# 1010                      Asus BR1100CKA-GJ0722W Laptop     Asus
# 1011             Lenovo Yoga 6 13ALC6 82ND00DPIN Laptop   Lenovo
# 1012                      Asus BR1100FKA-BP1104W Laptop     Asus
# 1013  Asus ROG Strix Scar 17 G733ZW-LL139WS Gaming L...     Asus
#
#          processor_name  ram(GB)  ssd(GB)  Hard Disk(GB) Operating System  \
# 0      11th Gen Core i3        8      512              0          Windows
# ...

# %%
df["price"].max()
# Out:
# 479990

# %%
df["price"].min()
# Out:
# 15990

# %%
df[df["price"] == 479990]
# Out:
#      Unnamed: 0                                         model_name brand  \
# 681         685  Asus ROG Strix Scar 17 SE G733CX-LL012WS Gamin...  Asus
#
#        processor_name  ram(GB)  ssd(GB)  Hard Disk(GB) Operating System  \
# 681  12th Gen Core i9       32     4000              0          Windows
#
#                             graphics  screen_size(inches) resolution (pixels)  \
# 681  16 GB NVIDIA GeForce RTX 3080Ti                 17.3         2560 x 1440
#
#      no_of_cores  no_of_threads  spec_score   price
# 681           16             24          86  479990

# %%
df["spec_score"].value_counts(dropna=False)
# Out:
# spec_score
# 69    50
# 61    45
# 67    44
# 62    41
# 59    40
# 56    39
# 72    38
# 63    38
# 60    35
# 68    35
# 65    35
# 66    33
# 71    32
# 57    31
# 55    31
# 54    31
# 74    30
# 73    28
# 53    27
# 75    26
# 76    24
# 51    24
# 50    23
# 48    21
# 47    19
# 79    18
# 78    16
# 49    15
# 84    15
# 81    14
# 82    14
# 86    11
# 45    10
# 44    10
# 0     10
# 80     9
# 85     8
# 91     8
# 87     5
# 41     4
# 43     4
# 42     3
# 94     3
# 88     2
# 93     2
# 97     1
# 90     1
# 96     1
# 92     1
# Name: count, dtype: int64

# %%
df[df["spec_score"] == 0]
# Out:
#      Unnamed: 0                                         model_name    brand  \
# 117         121          Asus Chromebook Flip C214MA-BU0704 Laptop     Asus
# 153         157                      Samsung Galaxy Book Go Laptop  Samsung
# 199         203                           HP 255 G8 6X4B2PA Laptop       HP
# 351         355                       Acer Extensa EX215-31 Laptop     Acer
# 461         465  Acer Chromebook Enterprise Spin 513 R841LT-S6D...     Acer
# 501         505                    Acer Chromebook 311 C733 Laptop     Acer
# 543         547                          Chuwi Gemibook Pro Laptop    Chuwi
# 618         622                         HP 250 G8 6G9R1PA Notebook       HP
# 666         670                Lenovo V14 G2-ITL 82KA00G8IH Laptop   Lenovo
# 892         896            Lenovo IdeaPad Slim 3 81X800LGIN Laptop   Lenovo
#
#           processor_name  ram(GB)  ssd(GB)  Hard Disk(GB) Operating System  \
# ...

# %%
df = df[df["spec_score"] != 0]

# %%
df.shape
# Out:
# (995, 15)

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df.shape
# Out:
# (995, 14)

# %%
df = df[df["ram(GB)"] >= 8]

# %%
df["ssd(GB)"].value_counts(dropna=False)
# Out:
# ssd(GB)
# 512     635
# 1000    174
# 256     109
# 0        12
# 2000     12
# 128       2
# 4000      1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (945, 14)

# %%
df["spec_score"].min()
# Out:
# 41

# %%
df["no_of_threads"].min()
# Out:
# 0

# %%
df["no_of_cores"].min()
# Out:
# 0

# %%
df["no_of_threads"].value_counts(dropna=False)
# Out:
# no_of_threads
# 12    254
# 16    239
# 8     194
# 4     119
# 20     93
# 0      28
# 2      11
# 24      6
# 6       1
# Name: count, dtype: int64

# %%
df["no_of_threads"].value_counts(dropna=False)
# Out:
# no_of_threads
# 12    254
# 16    239
# 8     194
# 4     119
# 20     93
# 0      28
# 2      11
# 24      6
# 6       1
# Name: count, dtype: int64

# %%
df = df[df["no_of_threads"] != 0]

# %%
df = df[df["no_of_cores"] != 0]

# %%
df[df["spec_score"] >= 60].shape
# Out:
# (658, 14)

# %%
df[df["spec_score"] == 41]
# Out:
#                                  model_name brand    processor_name  ram(GB)  \
# 26  Asus VivoBook 15 X1500EA-EJ322WS Laptop  Asus  11th Gen Core i3        8
# 56  Asus VivoBook 15 X1500EA-EJ322WS Laptop  Asus  11th Gen Core i3        8
#
#     ssd(GB)  Hard Disk(GB) Operating System            graphics  \
# 26      512              0          Windows  Intel UHD Graphics
# 56      512              0          Windows  Intel UHD Graphics
#
#     screen_size(inches) resolution (pixels)  no_of_cores  no_of_threads  \
# 26                 15.6         1920 x 1080            2              4
# 56                 15.6         1920 x 1080            2              4
#
#     spec_score  price
# 26          41  35978
# 56          41  35325

# %%
df.shape
# Out:
# (916, 14)

# %%
df["brand"].unique()

# %%
df.columns
# Out:
# Index(['model_name', 'brand', 'processor_name', 'ram(GB)', 'ssd(GB)',
#        'Hard Disk(GB)', 'Operating System', 'graphics', 'screen_size(inches)',
#        'resolution (pixels)', 'no_of_cores', 'no_of_threads', 'spec_score',
#        'price'],
#       dtype='object')

# %%
df["brand"].value_counts(dropna=False)
# Out:
# brand
# Asus         206
# Lenovo       178
# HP           178
# Dell         133
# Acer          63
# MSI           62
# Samsung       24
# Infinix       14
# Gigabyte      12
# Fujitsu       10
# Microsoft     10
# LG             7
# Xiaomi         4
# Honor          4
# Realme         3
# Chuwi          2
# AGB            2
# Huawei         2
# Nokia          1
# Avita          1
# Name: count, dtype: int64

# %%
df[df["brand"] == "Infinix"]
# Out:
#                                     model_name    brand    processor_name  \
# 43               Infinix INBook X1 XL11 Laptop  Infinix  10th Gen Core i3
# 45        Infinix Zero Book Series ZL12 Laptop  Infinix  12th Gen Core i7
# 158              Infinix INBook X1 XL11 Laptop  Infinix  10th Gen Core i5
# 202         Infinix INBook X2 Plus XL25 Laptop  Infinix  11th Gen Core i3
# 203         Infinix INBook X2 Plus XL25 Laptop  Infinix  11th Gen Core i7
# 204         Infinix INBook X2 Plus XL25 Laptop  Infinix  11th Gen Core i5
# 280         Infinix INBook X1 Slim XL21 Laptop  Infinix  10th Gen Core i5
# 286  Infinix INBook X1 Slim Series XL21 Laptop  Infinix  10th Gen Core i3
# 336              Infinix INBook X1 XL12 Laptop  Infinix  10th Gen Core i7
# 394         Infinix INBook X2 Plus XL25 Laptop  Infinix  11th Gen Core i5
# 526         Infinix INBook X2 Plus XL25 Laptop  Infinix  11th Gen Core i3
# 916         Infinix INBook X1 Slim XL21 Laptop  Infinix  10th Gen Core i5
# ...

# %%
# Out:
#                               model_name     brand    processor_name  ram(GB)  \
# 443         Gigabyte G5 KE RC55KE Laptop  Gigabyte  12th Gen Core i5       16
# 444         Gigabyte G5 ME RC55ME Laptop  Gigabyte  12th Gen Core i5       16
# 445         Gigabyte G5 GE RC55GE Laptop  Gigabyte  12th Gen Core i5        8
# 563            Gigabyte G5 RC45MD Laptop  Gigabyte  11th Gen Core i5       16
# 564            Gigabyte G5 RC45GD Laptop  Gigabyte  11th Gen Core i5       16
# 565            Gigabyte G5 RC45KD Laptop  Gigabyte  11th Gen Core i5       16
# 610      Gigabyte Aero 5 XE4 OLED Laptop  Gigabyte  12th Gen Core i7       16
# 658   Gigabyte Aorus 5 SE4 Gaming Laptop  Gigabyte  12th Gen Core i7       16
# 665      Gigabyte Aero 5 KE4 OLED Laptop  Gigabyte  12th Gen Core i7       16
# 706  Gigabyte Aorus 15 XE5 Gaming Laptop  Gigabyte  12th Gen Core i7       16
# 710  Gigabyte Aorus 15 XE4 Gaming Laptop  Gigabyte  12th Gen Core i7       16
# ...

# %%
#df = df[df["brand"] != "Realme"]
#df = df[df["brand"] != "Chuwi"]
#df = df[df["brand"] != "AGB"]
#df = df[df["brand"] != "Avita"]
#df = df[df["brand"] != "Honor"]
#df = df[df["brand"] != "Infinix"]

# %%
df.shape
# Out:
# (890, 14)

# %%
df.nunique()
# Out:
# model_name             825
# brand                   14
# processor_name          97
# ram(GB)                  5
# ssd(GB)                  7
# Hard Disk(GB)            2
# Operating System         3
# graphics               130
# screen_size(inches)     16
# resolution (pixels)     24
# no_of_cores              8
# no_of_threads            8
# spec_score              47
# price                  565
# dtype: int64

# %%
df_full=df.copy()

# %%
df["no_of_cores"].value_counts(dropna=False)
# Out:
# no_of_cores
# 4     166
# 8     165
# 6     137
# 10    127
# 2     117
# 14     90
# 12     82
# 16      6
# Name: count, dtype: int64

# %%
df[(df["spec_score"] >= 50) & (df["no_of_cores"] == 2)]
# Out:
#                                      model_name   brand  \
# 0           Lenovo V15 ITL G2 82KBA033IH Laptop  Lenovo
# 2                  Lenovo V15 82KBA03HIH Laptop  Lenovo
# 7                        HP 15s-eq1559AU Laptop      HP
# 9                     Dell Inspiron 3511 Laptop    Dell
# 16                       HP 15s-er1501AU Laptop      HP
# ..                                          ...     ...
# 971                     Dell Vostro 3405 Laptop    Dell
# 976  Lenovo IdeaPad 3 15IML05 81WB01EBIN Laptop  Lenovo
# 978  Lenovo IdeaPad 3 15IGL05 81WQ00MQIN Laptop  Lenovo
# 980   Lenovo IdeaPad 3 15ITL6 82H802L0IN Laptop  Lenovo
# 997     Lenovo IdeaPad Slim 3 81WE01QLIN Laptop  Lenovo
#
#               processor_name  ram(GB)  ssd(GB)  Hard Disk(GB)  \
# 0           11th Gen Core i3        8      512              0
# 2           11th Gen Core i3        8      256           1000
# 7    AMD Athlon Silver 3050U        8      512              0
# ...

# %%
df.shape
# Out:
# (890, 14)

# %%
df = df.drop(df.sample(frac=0.15).index)

# %%
df.shape
# Out:
# (376, 14)

# %%
df["brand"].unique()
# Out:
# array(['Lenovo', 'Asus', 'Dell', 'HP', 'MSI', 'Nokia', 'Samsung', 'Acer',
#        'Xiaomi', 'Gigabyte', 'Microsoft', 'Huawei', 'Fujitsu', 'LG'],
#       dtype=object)

# %%
df["processor_name"].unique()
# Out:
# array(['11th Gen Core i3', 'Ryzen 5-5600H', '11th Gen Core i5',
#        '12th Gen Core i3', 'Ryzen 7 5800H', '12th Gen Core i5',
#        'AMD Ryzen 5 4600H', '10th Gen Core i3', 'AMD Ryzen 5 5500U',
#        'AMD Ryzen 3 5300U', '11th Gen Core i7', 'Ryzen 5 5600H',
#        'AMD Ryzen 5-5600H', 'AMD Ryzen 5 5600H', '13th Gen Core i7',
#        '13th Gen Core i5', 'AMD Ryzen 5-5625U', 'Ryzen 5 5500U',
#        '12th Gen Core i7', 'AMD Ryzen 3 3250U', '12th Gen Core i9',
#        '2022) FX507ZE-HN038W Gaming Laptop ', '8LX79PA) Laptop ',
#        'Ryzen 3 5300U', 'Athlon 3050U', 'AMD Ryzen 7 5800H',
#        'AMD Ryzen 3 5425U', 'Intel Celeron N4020', 'Ryzen 7-4800H',
#        'Ryzen 3 3250U', 'AMD Ryzen3 5425U', '11th Gen Core i9',
#        'Ryzen 7 4800H', 'Ryzen 7-5800H', 'Celeron N4020',
#        'Ryzen 9 5900HX', 'Ryzen 5', 'AMD Ryzen 9', 'AMD Ryzen 7 6800H',
#        'Ryzen 5 5625U', 'AMD Ryzen 7 6800HS', 'Ryzen 7 5700U',
# ...

# %%
 df["ram(GB)"].unique()
# Out:
# array([ 8, 16, 64, 32, 12], dtype=int64)

# %%
df["ssd(GB)"].unique()
# Out:
# array([ 512,  256,    0, 1000, 2000, 4000,  128], dtype=int64)

# %%
df["Operating System"].unique()
# Out:
# array(['Windows', 'DOS', 'Ubuntu'], dtype=object)

# %%
df["graphics"].unique()
# Out:
# array(['Intel Integrated UHD', 'AMD Radeon Vega 7',
#        '4\u2009GB NVIDIA GeForce GTX 1650', 'Intel UHD Graphics',
#        'AMD Radeon Vega 7 Graphics', 'AMD Radeon Graphics',
#        'Intel Iris Xe', 'Intel Iris XE Graphics',
#        'Intel Iris Xe Graphics', 'Intel Integrated Iris Xe',
#        '4\u2009GB NVIDIA GeForce RTX 3050',
#        '4\u2009GB NVIDIA GeForce GTX 1650 MAX Q',
#        '\u200eIntel Iris Xe Graphics', 'AMD Radeon Radeon Graphics',
#        'AMD Radeon AMD', 'Intel iris Xe Integrated',
#        '2\u2009GB NVIDIA GeForce MX550',
#        '6\u2009GB NVIDIA GeForce RTX 3060',
#        'Intel Integrated UHD Graphics',
#        '4\u2009GB NVIDIA GeForce RTX 3050-Ti',
#        '4\u2009GB NVIDIA GeForce RTX 3050Ti',
#        '4\u2009GB AMD Radeon RX 5500M', '2\u2009GB NVIDIA GeForce MX350',
#        'Integrated UHD Graphics 620', 'Intel Iris Xe Integrated Graphics',
#        'Intel Integrated Intel UHD',
# ...

# %%
df["screen_size(inches)"].unique()
# Out:
# array([15.6 , 16.  , 14.  , 17.3 , 14.1 , 13.3 , 16.1 , 13.4 , 13.5 ,
#        13.  , 14.5 , 17.32, 17.  , 12.4 ])

# %%
df["resolution (pixels)"].unique()
# Out:
# array(['1920 x 1080', '1200 x 1920', '1920 x 1200', '2880 x 1800',
#        '1080 x 1920', '1366 x 768', '2560 x 1440', '2560 x 1600',
#        '3840 x 2400', '3840 x 2160', '2256 x 1504', '2880 x 1920',
#        '2160 x 1440', '3072 x 1920', '2240 x 1400', '1600 x 2560',
#        '3000 x 2000', '1536 x 1024'], dtype=object)

# %%
df["no_of_cores"].unique()
# Out:
# array([ 2,  6,  4,  8, 10, 12, 14, 16], dtype=int64)

# %%
df["no_of_threads"].unique()
# Out:
# array([ 4, 12,  8, 16, 20,  2, 24], dtype=int64)

# %%
df["spec_score"].unique()
# Out:
# array([62, 66, 73, 61, 68, 55, 69, 67, 51, 56, 60, 41, 59, 71, 65, 63, 72,
#        54, 74, 81, 75, 76, 79, 53, 57, 78, 47, 84, 86, 85, 49, 97, 48, 50,
#        80, 96, 94, 91, 87, 82, 88], dtype=int64)

# %%
df.shape
# Out:
# (376, 14)

# %%
df.nunique()
# Out:
# model_name             363
# brand                   14
# processor_name          62
# ram(GB)                  5
# ssd(GB)                  7
# Hard Disk(GB)            2
# Operating System         3
# graphics                82
# screen_size(inches)     14
# resolution (pixels)     18
# no_of_cores              8
# no_of_threads            7
# spec_score              41
# price                  279
# dtype: int64

# %%
df_cropped=df.copy()

# %%
df.isnull().sum()
# Out:
# model_name             0
# brand                  0
# processor_name         0
# ram(GB)                0
# ssd(GB)                0
# Hard Disk(GB)          0
# Operating System       0
# graphics               0
# screen_size(inches)    0
# resolution (pixels)    0
# no_of_cores            0
# no_of_threads          0
# spec_score             0
# price                  0
# dtype: int64

# %%
df = df.drop(columns=["spec_score"])

# %%
df.shape
# Out:
# (376, 13)

# %%
df.to_csv(r"C:\Users\LESLIN\Desktop\Laptop recommender\data\laptop_cleaned.csv", index=False)
